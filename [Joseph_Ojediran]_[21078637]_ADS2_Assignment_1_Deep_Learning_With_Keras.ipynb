# %% [markdown]
# <a href="https://colab.research.google.com/github/jossy450/assignment/blob/main/%5BJoseph_Ojediran%5D_%5B21078637%5D_ADS2_Assignment_1_Deep_Learning_With_Keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment 1 - Deep Learning With Keras - 40%
#
# **IMPORTANT NOTE**: By default, this notebook is set to a CPU runtime, to help prevent you getting locked out of Google Colab. When training your models, you will need to switch to a GPU runtime, otherwise the training will take a very long time.
#
# **Deadline**: 21 Mar 2023, 23:59
#
# **Submission Requirements**: You should submit your Colab Notebook, with all the outputs printed, and a sharing link to the notebook in your Drive. As detailed above, you should submit a 2-page report in PDF or DOCX format.
#
# **Learning Outcomes**
#
# This Assignment assesses the following module Learning Outcomes (from Definitive Module Document):
#
# * have knowledge of and understand how GPUs can accelerate data processing
# * be able to write data processing pipelines that exploit Tensorflow
# * have knowledge of and understand how to develop GPU-accelerated data processing pipelines using the Tensorflow and RAPIDS frameworks
#
# **Assignment Details**
#
# This assignment will test your ability to implement and test a deep neural network using keras. By varying the properties of the model and the data input pipeline, you will explore and analyse the training time and performance of the model. There will be four tasks for you to complete, each of which requires you to complete a range of tests on the model, visualise the results, and comment on them in a short report. Your report should focus on explaining and critically analysing the results—you will be assessed not just on your ability to show what is happening, but explain WHY it is happening.
#
# All coding work for this assignment should be done inside a copy of the Colab Notebook provided on this page. Any submissions not in this format will not be marked.
#
# **Task 1**: A model description is provided in the Colab Notebook for this assignment. Implement this model, ensuring that you have the correct output shapes for each of the layers and the correct number of model parameters. Train the model on the dataset provided in the notebook—initial training settings are provided also. Create plots of the losses and metrics of the training and validation data, and a plot that shows example images from each class that have been correctly AND incorrectly labelled by the model. Analyse these results in your report.
#
# **Task 2**: Select two additional optimizers. Including the one provided in the initial training settings, test your model with each of these optimizers using a range of different learning rates. You may need to train the model for more epochs to ensure that it converges on a solution. Create plots that show the losses and metrics for each of these runs, and comment on the results in your report. Select the optimizer and learning rate that provided the best results, and move onto the next task.
#
# **Task 3**: The batch size can heavily influence the amount of time it takes to train a model. Vary the batch size used to train the model and, utilising the Early Stopping callback provided, create plots that show how the time per epoch and total training time changes. Comment on these results in your report.
#
# **Task 4**: The model as provided does not contain any regularisation techniques. Edit the model architecture to include at least two examples of regularisation. Retrain the model using the new architecture, and repeat the analysis performed in task 1. In your report, compare and contrast the results from this task, with those from the initial model configuration.

# %%
# Module Imports - Add any additional modules here
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras 
from keras import layers,models,optimizers,losses, callbacks,\
                             regularizers
from keras.layers import Rescaling

# %%
# @title Default title text
# Loading the Dataset. Here we use the CIFAR-10 dataset of labelled images

(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

# Rescale the pixel values
x_train = x_train/255
x_test = x_test/255

# List of label names
class_names = ['plane', 'car', 'bird', 'cat', 'deer',
               'canine', 'frog', 'horse', 'boat', 'truck']

# %% [markdown]
# # Task 1 - Initial Model
#
# Implement the model architecture detailed below, using the Keras Functional API, ensuring that you have the correct output shapes for each of the layers.
#
# Train the model on the CIFAR-10 dataset.
#
# Create plots of the losses and metrics of the training and validation data, and plots that show example test images from each class that have been correctly AND incorrectly labelled by the model.
#
# Analyse these results in your report.
#
# **Model Architecture**
#
# A summary of the model architecture is given here, which shows the layers of the model, the output shapes of those layers, and the activation functions used. You will need to work out the other settings used to produce the model, such as the kernal sizes, padding schemes, and stride lengths. You should ensure that the output shapes and total number of parameters in your model match the summary here.
#
# ```
# Model: "cifar_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Activation
# =================================================================
#  Input (InputLayer)          [(None, 32, 32, 3)]       None
#
#  conv_1 (Conv2D)             (None, 32, 32, 16)        ReLU
#
#  conv_2 (Conv2D)             (None, 32, 32, 16)        ReLU
#
#  pool_1 (MaxPooling2D)       (None, 16, 16, 16)        None
#
#  conv_3 (Conv2D)             (None, 16, 16, 32)        ReLU
#
#  conv_4 (Conv2D)             (None, 16, 16, 32)        ReLU
#
#  pool_2 (MaxPooling2D)       (None, 8, 8, 32)          None
#
#  conv_5 (Conv2D)             (None, 8, 8, 64)          ReLU
#
#  conv_6 (Conv2D)             (None, 8, 8, 64)          ReLU
#
#  pool_3 (MaxPooling2D)       (None, 4, 4, 64)          None
#
#  flat (Flatten)              (None, 1024)              None
#
#  fc_1 (Dense)                (None, 512)               ReLU
#
#  Output (Dense)              (None, 10)                SoftMax
#
# =================================================================
# Total params: 602,010
# Trainable params: 602,010
# Non-trainable params: 0
# _________________________________________________________________
# ```

# %%
### Create the model using the provided architecture
# Define the input shape
input_shape = (32, 32, 3)

# Define the model architecture using the Keras Functional API
inputs = layers.Input(shape=input_shape)
x = layers.Conv2D(32, (3, 3), activation='relu')(inputs)
x = layers.MaxPooling2D((2, 2))(x)
x = layers.Conv2D(64, (3, 3), activation='relu')(x)
x = layers.MaxPooling2D((2, 2))(x)
x = layers.Conv2D(128, (3, 3), activation='relu')(x)
x = layers.MaxPooling2D((2, 2))(x)
x = layers.Flatten()(x)
x = layers.Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.001))(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(10, activation='softmax')(x)

model = models.Model(inputs=inputs, outputs=outputs)

# %%
### Compile the model using the SGC optimizer, with default learning rate,
# Sparse Categorical Crossentropy loss and Accuracy metric
#model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.1, momentum=0.9, nesterov=True),
 #             loss=tf.keras.losses.SparseCategoricalCrossentropy(),
  #            metrics=['accuracy'])


lr_schedule = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=0.01,
    decay_steps=10000,
    decay_rate=0.9)
sgd = tf.keras.optimizers.SGD(learning_rate=lr_schedule)

model.compile(optimizer=sgd,
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])

# %%
### Train the model for 50 epochs, with a batch size of 128. Include the test
### data for model validation. Store the losses and metrics in a history object.

history = model.fit(x_train, y_train, epochs=50, batch_size=128, validation_data=(x_test, y_test))
# Out:
# Epoch 1/50
# 391/391 [==============================] - 4s 8ms/step - loss: 2.4915 - accuracy: 0.1313 - val_loss: 2.4653 - val_accuracy: 0.2034
# Epoch 2/50
# 391/391 [==============================] - 3s 6ms/step - loss: 2.4105 - accuracy: 0.1877 - val_loss: 2.3057 - val_accuracy: 0.2550
# Epoch 3/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.
50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.3932 - accuracy: 0.5540 - val_loss: 1.3103 - val_accuracy: 0.5886
# Epoch 33/50
# 391/391 [==============================] - 3s 6ms/step - loss: 1.3781 - accuracy: 0.5630 - val_loss: 1.3136 - val_accuracy: 0.5874
# Epoch 34/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.3622 - accuracy: 0.5674 - val_loss: 1.2792 - val_accuracy: 0.5986
# Epoch 35/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.3512 - accuracy: 0.5730 - val_loss: 1.3081 - val_accuracy: 0.5844
# Epoch 36/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.3385 - accuracy: 0.5773 - val_loss: 1.2851 - val_accuracy: 0.5966
# Epoch 37/50
# 391/391 [==============================] - 3s 6ms/step - loss: 1.3303 - accuracy: 0.5786 - val_loss: 1.2414 - val_accuracy: 0.6090
# Epoch 38/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.3140 - accuracy: 0.5824 - val_loss: 1.2380 - val_accuracy: 0.6118
# Epoch 39/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.2981 - accuracy: 0.5860 - val_loss: 1.2593 - val_accuracy: 0.5928
# Epoch 40/50
# 391/391 [==============================] - 3s 6ms/step - loss: 1.2878 - accuracy: 0.5941 - val_loss: 1.2181 - val_accuracy: 0.6199
# Epoch 41/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.2752 - accuracy: 0.5978 - val_loss: 1.2109 - val_accuracy: 0.6178
# Epoch 42/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.2635 - accuracy: 0.5996 - val_loss: 1.2441 - val_accuracy: 0.6036
# Epoch 43/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.2553 - accuracy: 0.6035 - val_loss: 1.1907 - val_accuracy: 0.6253
# Epoch 44/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.2450 - accuracy: 0.6097 - val_loss: 1.2068 - val_accuracy: 0.6164
# Epoch 45/50
# 391/391 [==============================] - 3s 6ms/step - loss: 1.2325 - accuracy: 0.6117 - val_loss: 1.1899 - val_accuracy: 0.6218
# Epoch 46/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.2226 - accuracy: 0.6134 - val_loss: 1.1854 - val_accuracy: 0.6264
# Epoch 47/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.2144 - accuracy: 0.6164 - val_loss: 1.1511 - val_accuracy: 0.6398
# Epoch 48/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.2066 - accuracy: 0.6202 - val_loss: 1.2151 - val_accuracy: 0.6088
# Epoch 49/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.1966 - accuracy: 0.6216 - val_loss: 1.1355 - val_accuracy: 0.6439
# Epoch 50/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.1852 - accuracy: 0.6265 - val_loss: 1.1315 - val_accuracy: 0.6454

# %%
### Create plots of the losses and metrics of the training and validation data,
### and plots that shows example test images from each class that have been
### correctly AND incorrectly labelled by the model.

# Plot the training and validation losses and accuracy
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.title('Training and Validation Losses')

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend()
plt.title('Training and Validation Accuracy')
plt.show()

# Get predicted labels for the test data
y_pred = np.argmax(model.predict(x_test), axis=-1)

# Plot examples of correctly and incorrectly labeled test images for each class
num_classes = len(class_names)

plt.figure(figsize=(10, 10))
for i in range(num_classes):
    class_indices = np.where(y_test == i)[0]
    correct_indices = np.where(y_pred[class_indices] == i)[0]
    incorrect_indices = np.where(y_pred[class_indices] != i)[0]

    plt.subplot(1, num_classes, i+1)
    plt.imshow(x_test[class_indices[correct_indices[0]]])
    plt.title(class_names[i])
    plt.axis('off')

    if len(incorrect_indices) > 0:
        plt.subplot(1, num_classes+(i+1),num_classes)
        plt.imshow(x_test[class_indices[incorrect_indices[0]]])
        plt.title(class_names[i])
        plt.axis('off')
        
plt.show()
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %% [markdown]
# # Task 2 - Testing Optimizers
#
# Select two additional optimizers. Including the SGD algorithm already used, test all three of these optimizers with a range of different learning rates.
#
# You may need to train the model for more or less epochs to ensure that it converges on a solution.
#
# Create plots that show the losses and metrics for each of these runs, and comment on the results in your report.
#
# Select the optimizer and learning rate that provided the best results, and move onto the next task.
#
# **Note**: You should reset the weights of the model between each test. A function is provided to perform this task. Store the losses and metrics of each run under a different variable name, so that they can all be plotted together.

# %%
# Utility function that resets the weights of your model. Call this before
# recompiling your model with updated settings, to ensure you train the model
# from scratch.

def reinitialize(model):
    # Loop over the layers of the model
    for l in model.layers:
        # Check if the layer has initializers
        if hasattr(l,"kernel_initializer"):
            # Reset the kernel weights
            l.kernel.assign(l.kernel_initializer(tf.shape(l.kernel)))
        if hasattr(l,"bias_initializer"):
            # Reset the bias
            l.bias.assign(l.bias_initializer(tf.shape(l.bias)))

# Function modified from here: https://stackoverflow.com/questions/63435679/reset-all-weights-of-keras-model



# Define the optimizers to test and the learning rates to use
optimizers_to_test = {'SGD': [0.001, 0.01, 0.1],
                      'Adam': [0.0001, 0.001, 0.01],
                      'Adagrad': [0.001, 0.01, 0.1]}
num_runs = len(optimizers_to_test) * len(optimizers_to_test['SGD'])

# Define a function to reset the model weights
def reset_weights(model):
    for layer in model.layers:
        if hasattr(layer, 'reset_weights'):
            layer.reset_weights()

# %%
### Test the SGD Optimizer, plus two others of your choice, with a range of
### learning rates.

# Define the optimizers to test
optimizers = {
    'SGD': tf.keras.optimizers.SGD,
    'Adam': tf.keras.optimizers.Adam,
    'Adagrad': tf.keras.optimizers.Adagrad
}

# Define the learning rates to test
learning_rates = [0.001, 0.01, 0.1, 1.0]

# Initialize lists to store the losses and metrics for each run
history_list = []
optimizer_list = []
lr_list = []

# Iterate over the optimizers and learning rates to test
for optimizer_name, optimizer_class in optimizers.items():
    for lr in learning_rates:
        print(f'Testing {optimizer_name} optimizer with learning rate {lr}')

        # Reset the model weights
        reset_weights(model)

        # Compile the model with the current optimizer and learning rate
        optimizer = optimizer_class(learning_rate=lr)
        model.compile(optimizer=optimizer,
                      loss=losses.SparseCategoricalCrossentropy(),
                      metrics=['accuracy'])

        # Train the model for 50 epochs with a batch size of 128
        history = model.fit(x_train, y_train, epochs=50, batch_size=128, validation_data=(x_test, y_test))

        # Add the losses and metrics to the lists
        history_list.append(history)
        optimizer_list.append(optimizer_name)
        lr_list.append(lr)
# Out:
# Testing SGD optimizer with learning rate 0.001
# Epoch 1/50
# 391/391 [==============================] - 13s 8ms/step - loss: 2.5083 - accuracy: 0.1044 - val_loss: 2.4985 - val_accuracy: 0.1294
# Epoch 2/50
# 391/391 [==============================] - 3s 7ms/step - loss: 2.4994 - accuracy: 0.1174 - val_loss: 2.4937 - val_accuracy: 0.1656
# Epoch 3/50
# 391/391 [==============================] - 3s 7ms/step - loss: 2.4940 - accuracy: 0.1306 - val_loss: 2.4893 - val_accuracy: 0.1804
# Epoch 4/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.4895 - accuracy: 0.1399 - val_loss: 2.4843 - val_accuracy: 0.1951
# Epoch 5/50
# 391/391 [==============================] - 3s 7ms/step - loss: 2
50
# 391/391 [==============================] - 3s 6ms/step - loss: 1.6986 - accuracy: 0.4497 - val_loss: 1.6083 - val_accuracy: 0.4879
# Epoch 10/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.6789 - accuracy: 0.4562 - val_loss: 1.5814 - val_accuracy: 0.5050
# Epoch 11/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.6547 - accuracy: 0.4647 - val_loss: 1.5976 - val_accuracy: 0.4948
# Epoch 12/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.6302 - accuracy: 0.4720 - val_loss: 1.5515 - val_accuracy: 0.5076
# Epoch 13/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.6050 - accuracy: 0.4812 - val_loss: 1.5354 - val_accuracy: 0.5152
# Epoch 14/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.5870 - accuracy: 0.4911 - val_loss: 1.4890 - val_accuracy: 0.5291
# Epoch 15/50
# 391/391 [==============================] - 3s 6ms/step - loss: 1.5673 - accuracy: 0.4970 - val_loss: 1.5022 - val_accuracy: 0.5225
# Epoch 16/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.5441 - accuracy: 0.5044 - val_loss: 1.4487 - val_accuracy: 0.5404
# Epoch 17/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.5248 - accuracy: 0.5099 - val_loss: 1.4561 - val_accuracy: 0.5399
# Epoch 18/50
# 391/391 [==============================] - 3s 6ms/step - loss: 1.5070 - accuracy: 0.5163 - val_loss: 1.4120 - val_accuracy: 0.5549
# Epoch 19/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.4897 - accuracy: 0.5245 - val_loss: 1.3887 - val_accuracy: 0.5615
# Epoch 20/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.4697 - accuracy: 0.5307 - val_loss: 1.4255 - val_accuracy: 0.5444
# Epoch 21/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.4494 - accuracy: 0.5369 - val_loss: 1.4203 - val_accuracy: 0.5583
# Epoch 22/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.4372 - accuracy: 0.5433 - val_loss: 1.4015 - val_accuracy: 0.5511
# Epoch 23/50
# 391/391 [==============================] - 3s 6ms/step - loss: 1.4206 - accuracy: 0.5487 - val_loss: 1.3510 - val_accuracy: 0.5708
# Epoch 24/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.3999 - accuracy: 0.5557 - val_loss: 1.3525 - val_accuracy: 0.5683
# Epoch 25/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.3888 - accuracy: 0.5604 - val_loss: 1.3456 - val_accuracy: 0.5740
# Epoch 26/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.3743 - accuracy: 0.5635 - val_loss: 1.3036 - val_accuracy: 0.5879
# Epoch 27/50
# 391/391 [==============================] - 3s 6ms/step - loss: 1.3550 - accuracy: 0.5686 - val_loss: 1.2767 - val_accuracy: 0.5965
# Epoch 28/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.3428 - accuracy: 0.5748 - val_loss: 1.2733 - val_accuracy: 0.6006
# Epoch 29/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.3313 - accuracy: 0.5773 - val_loss: 1.2607 - val_accuracy: 0.6036
# Epoch 30/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.3165 - accuracy: 0.5859 - val_loss: 1.2784 - val_accuracy: 0.5911
# Epoch 31/50
# 391/391 [==============================] - 3s 6ms/step - loss: 1.3014 - accuracy: 0.5869 - val_loss: 1.2479 - val_accuracy: 0.6056
# Epoch 32/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.2851 - accuracy: 0.5932 - val_loss: 1.2316 - val_accuracy: 0.6114
# Epoch 33/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.2759 - accuracy: 0.5942 - val_loss: 1.2385 - val_accuracy: 0.6060
# Epoch 34/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.2642 - accuracy: 0.6007 - val_loss: 1.2130 - val_accuracy: 0.6202
# Epoch 35/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.2498 - accuracy: 0.6027 - val_loss: 1.2079 - val_accuracy: 0.6180
# Epoch 36/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.2379 - accuracy: 0.6122 - val_loss: 1.1787 - val_accuracy: 0.6343
# Epoch 37/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.2243 - accuracy: 0.6124 - val_loss: 1.1876 - val_accuracy: 0.6257
# Epoch 38/50
# 391/391 [==============================] - 3s 6ms/step - loss: 1
50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.7846 - accuracy: 0.7515 - val_loss: 0.9820 - val_accuracy: 0.6899
# Epoch 18/50
# 391/391 [==============================] - 3s 7ms/step - loss: 0.7694 - accuracy: 0.7566 - val_loss: 0.9920 - val_accuracy: 0.6906
# Epoch 19/50
# 391/391 [==============================] - 3s 7ms/step - loss: 0.7488 - accuracy: 0.7626 - val_loss: 1.0109 - val_accuracy: 0.6940
# Epoch 20/50
# 391/391 [==============================] - 3s 7ms/step - loss: 0.7265 - accuracy: 0.7706 - val_loss: 0.9629 - val_accuracy: 0.7021
# Epoch 21/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.7096 - accuracy: 0.7771 - val_loss: 1.0374 - val_accuracy: 0.6793
# Epoch 22/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.6982 - accuracy: 0.7788 - val_loss: 1.0086 - val_accuracy: 0.6949
# Epoch 23/50
# 391/391 [==============================] - 3s 7ms/step - loss: 0.6842 - accuracy: 0.7845 - val_loss: 1.0122 - val_accuracy: 0.6954
# Epoch 24/50
# 391/391 [==============================] - 3s 7ms/step - loss: 0.6693 - accuracy: 0.7919 - val_loss: 0.9817 - val_accuracy: 0.7002
# Epoch 25/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.6497 - accuracy: 0.7967 - val_loss: 1.0054 - val_accuracy: 0.7067
# Epoch 26/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.6417 - accuracy: 0.8002 - val_loss: 1.0883 - val_accuracy: 0.6958
# Epoch 27/50
# 391/391 [==============================] - 3s 7ms/step - loss: 0.6314 - accuracy: 0.8066 - val_loss: 1.0191 - val_accuracy: 0.7029
# Epoch 28/50
# 391/391 [==============================] - 3s 7ms/step - loss: 0.6138 - accuracy: 0.8118 - val_loss: 1.0490 - val_accuracy: 0.7028
# Epoch 29/50
# 391/391 [==============================] - 3s 7ms/step - loss: 0.6048 - accuracy: 0.8155 - val_loss: 1.0766 - val_accuracy: 0.6938
# Epoch 30/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.5889 - accuracy: 0.8191 - val_loss: 1.0587 - val_accuracy: 0.7033
# Epoch 31/50
# 391/391 [==============================] - 3s 7ms/step - loss: 0.5801 - accuracy: 0.8237 - val_loss: 1.1550 - val_accuracy: 0.6859
# Epoch 32/50
# 391/391 [==============================] - 3s 7ms/step - loss: 0.5628 - accuracy: 0.8294 - val_loss: 1.1805 - val_accuracy: 0.6800
# Epoch 33/50
# 391/391 [==============================] - 3s 7ms/step - loss: 0.5603 - accuracy: 0.8303 - val_loss: 1.0824 - val_accuracy: 0.7012
# Epoch 34/50
# 391/391 [==============================] - 3s 7ms/step - loss: 0.5519 - accuracy: 0.8347 - val_loss: 1.1409 - val_accuracy: 0.6940
# Epoch 35/50
# 391/391 [==============================] - 3s 7ms/step - loss: 0.5346 - accuracy: 0.8390 - val_loss: 1.2215 - val_accuracy: 0.6852
# Epoch 36/50
# 391/391 [==============================] - 3s 7ms/step - loss: 0.5359 - accuracy: 0.8390 - val_loss: 1.1418 - val_accuracy: 0.6962
# Epoch 37/50
# 391/391 [==============================] - 3s 7ms/step - loss: 0.5290 - accuracy: 0.8428 - val_loss: 1.1997 - val_accuracy: 0.6901
# Epoch 38/50
# 391/391 [==============================] - 3s 7ms/step - loss: 0.5156 - accuracy: 0.8474 - val_loss: 1.1324 - val_accuracy: 0.7020
# Epoch 39/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.5136 - accuracy: 0.8477 - val_loss: 1.1973 - val_accuracy: 0.6896
# Epoch 40/50
# 391/391 [==============================] - 3s 7ms/step - loss: 0.4991 - accuracy: 0.8536 - val_loss: 1.3688 - val_accuracy: 0.6728
# Epoch 41/50
# 391/391 [==============================] - 3s 7ms/step - loss: 0.4891 - accuracy: 0.8568 - val_loss: 1.2161 - val_accuracy: 0.6926
# Epoch 42/50
# 391/391 [==============================] - 3s 7ms/step - loss: 0.4894 - accuracy: 0.8585 - val_loss: 1.1707 - val_accuracy: 0.6969
# Epoch 43/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.4743 - accuracy: 0.8607 - val_loss: 1.2153 - val_accuracy: 0.6977
# Epoch 44/50
# 391/391 [==============================] - 3s 7ms/step - loss: 0.4750 - accuracy: 0.8623 - val_loss: 1.3924 - val_accuracy: 0.6748
# Epoch 45/50
# 391/391 [==============================] - 3s 7ms/step - loss: 0.4673 - accuracy: 0.8654 - val_loss: 1.2411 - val_accuracy: 0.6987
# Epoch 46/50
# 391/391 [==============================] - 3s 7ms/step - loss: 0.4570 - accuracy: 0.8689 - val_loss: 1.3135 - val_accuracy: 0.6945
# Epoch 47/50
# 391/391 [==============================] - 3s 7ms/step - loss: 0.4478 - accuracy: 0.8735 - val_loss: 1.3212 - val_accuracy: 0.6885
# Epoch 48/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.4459 - accuracy: 0.8749 - val_loss: 1.2835 - val_accuracy: 0.6959
# Epoch 49/50
# 391/391 [==============================] - 3s 7ms/step - loss: 0.4471 - accuracy: 0.8756 - val_loss: 1.2452 - val_accuracy: 0.7012
# Epoch 50/50
# 391/391 [==============================] - 3s 7ms/step - loss: 0.4391 - accuracy: 0.8789 - val_loss: 1.2957 - val_accuracy: 0.6956
# Testing SGD optimizer with learning rate 1.0
# Epoch 1/50
# 391/391 [==============================] - 5s 10ms/step - loss: nan - accuracy: 0.1025 - val_loss: nan - val_accuracy: 0.1000
# Epoch 2/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 3/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 4/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 5/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 6/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 7/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 8/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 9/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 10/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 11/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 12/50
# 391/391 [==============================] - 3s 6ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 13/50
# 391/391 [==============================] - 3s 6ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 14/50
# 391/391 [==============================] - 3s 6ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 15/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 16/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 17/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 18/50
# 391/391 [==============================] - 3s 6ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 19/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 20/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 21/50
# 391/391 [==============================] - 3s 6ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 22/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 23/50
# 391/391 [==============================] - 3s 6ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 24/50
# 391/391 [==============================] - 3s 9ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 25/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 26/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 27/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 28/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 29/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 30/50
# 391/391 [==============================] - 3s 6ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 31/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 32/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 33/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 34/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 35/50
# 391/391 [==============================] - 2s 6ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 36/50
# 391/391 [==============================] - 3s 6ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 37/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 38/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 39/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 40/50
# 391/391 [==============================] - 3s 6ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 41/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 42/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 43/50
# 391/391 [==============================] - 3s 6ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 44/50
# 391/391 [==============================] - 3s 6ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 45/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 46/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 47/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 48/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 49/50
# 391/391 [==============================] - 3s 6ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 50/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Testing Adam optimizer with learning rate 0.001
# Epoch 1/50
# 391/391 [==============================] - 6s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 2/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 3/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 4/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 5/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 6/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 7/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 8/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 9/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 10/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 11/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 12/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 13/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 14/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 15/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 16/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 17/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 18/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 19/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 20/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 21/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 22/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 23/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 24/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 25/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 26/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 27/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 28/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 29/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 30/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 31/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 32/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 33/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 34/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 35/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 36/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 37/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 38/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 39/50
# 391/391 [==============================] - 3s 9ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 40/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 41/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 42/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 43/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 44/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 45/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 46/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 47/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 48/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 49/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 50/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Testing Adam optimizer with learning rate 0.01
# Epoch 1/50
# 391/391 [==============================] - 6s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 2/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 3/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 4/50
# 391/391 [==============================] - 3s 9ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 5/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 6/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 7/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 8/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 9/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 10/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 11/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 12/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 13/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 14/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 15/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 16/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 17/50
# 391/391 [==============================] - 4s 9ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 18/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 19/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 20/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 21/50
# 391/391 [==============================] - 3s 9ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 22/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 23/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 24/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 25/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 26/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 27/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 28/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 29/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 30/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 31/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 32/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 33/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 34/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 35/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 36/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 37/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 38/50
# 391/391 [==============================] - 3s 9ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 39/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 40/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 41/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 42/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 43/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 44/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 45/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 46/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 47/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 48/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 49/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 50/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Testing Adam optimizer with learning rate 0.1
# Epoch 1/50
# 391/391 [==============================] - 5s 9ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 2/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 3/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 4/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 5/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 6/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 7/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 8/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 9/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 10/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 11/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 12/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 13/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 14/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 15/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 16/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 17/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 18/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 19/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 20/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 21/50
# 391/391 [==============================] - 4s 9ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 22/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 23/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 24/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 25/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 26/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 27/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 28/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 29/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 30/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 31/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 32/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 33/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 34/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 35/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 36/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 37/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 38/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 39/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 40/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 41/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 42/50
# ...
# Epoch 35/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 36/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 37/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 38/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 39/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 40/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 41/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 42/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 43/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 44/50
# 391/391 [==============================] - 3s 9ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 45/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 46/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 47/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 48/50
# 391/391 [==============================] - 3s 9ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 49/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 50/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Testing Adagrad optimizer with learning rate 0.1
# Epoch 1/50
# 391/391 [==============================] - 5s 9ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 2/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 3/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 4/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 5/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 6/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 7/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 8/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 9/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 10/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 11/50
# 391/391 [==============================] - 3s 9ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 12/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 13/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 14/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 15/50
# 391/391 [==============================] - 4s 9ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 16/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 17/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 18/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 19/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 20/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 21/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 22/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 23/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 24/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 25/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 26/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 27/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 28/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 29/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 30/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 31/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 32/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 33/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 34/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 35/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 36/50
# 391/391 [==============================] - 3s 9ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 37/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 38/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 39/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 40/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 41/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 42/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 43/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 44/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 45/50
# 391/391 [==============================] - 3s 9ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 46/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 47/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 48/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 49/50
# 391/391 [==============================] - 3s 9ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 50/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Testing Adagrad optimizer with learning rate 1.0
# Epoch 1/50
# 391/391 [==============================] - 5s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 2/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 3/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 4/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 5/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 6/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 7/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 8/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 9/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 10/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 11/50
# 391/391 [==============================] - 3s 9ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 12/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 13/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 14/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 15/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 16/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 17/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 18/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 19/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 20/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 21/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 22/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 23/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 24/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 25/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 26/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 27/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 28/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 29/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 30/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 31/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 32/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 33/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 34/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 35/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 36/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 37/50
# 391/391 [==============================] - 4s 9ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 38/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 39/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 40/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 41/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 42/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 43/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 44/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 45/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 46/50
# 391/391 [==============================] - 3s 8ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 47/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 48/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 49/50
# 391/391 [==============================] - 3s 7ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 50/50
# 391/391 [==============================] - 3s 9ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000

# %%
### Create plots that show the losses and metrics for each of these runs, and
### comment on the results in your report.

# Plot the losses and accuracies for each run
num_cols = len(optimizers_to_test['SGD'])
num_rows = len(optimizers_to_test)
fig, axs = plt.subplots(num_rows, num_cols, figsize=(20, 10))
for i in range(num_rows):
    for j in range(num_cols):
        index = i * num_cols + j
        history = history_list[index]
        optimizer = optimizer_list[index]
        lr = lr_list[index]

        axs[i, j].plot(history.history['loss'], label='Training Loss')
        axs[i, j].plot(history.history['val_loss'], label='Validation Loss')
        axs[i, j].plot(history.history['accuracy'], label='Training Accuracy')
        axs[i, j].plot(history.history['val_accuracy'], label='Validation Accuracy')
        axs[i, j].set_title(f'{optimizer} with LR {lr}')
        axs[i, j].legend()
plt.show()

# %% [markdown]
# # Task 3 - Testing Batch Sizes
#
# The batch size can heavily influence the amount of time it takes to train a model. Vary the batch size used to train the model and, utilising the Early Stopping callback provided, create plots that show how the time per epoch and total training time changes.
#
# Comment on these results in your report—consider both how the batch size influences the number of epochs it takes to reach a solution, and how long each epoch takes to run. Why is this the case?

# %%
### Train the model with a range of different batch sizes, resetting the weights
### each time. Use an Early Stopping callback to prevent the model training for
### too long.

# Reset the model weights function
def reset_weights(model):
    for layer in model.layers:
        if hasattr(layers, 'kernel_initializer'):
          layers.kernel.initializer.run(session=layer.get_session())

# Define a range of batch sizes to test
batch_sizes = [16, 32, 64, 128, 256]

# Train the model with different batch sizes
histories = []
for batch_size in batch_sizes:
    print(f'Training model with batch size {batch_size}...')
    reset_weights(model)
    history = model.fit(x_train, y_train,
                        batch_size=batch_size,
                        epochs=50,
                        validation_data=(x_test, y_test),
                        callbacks=[callbacks.EarlyStopping(monitor='val_loss', patience=3)])
    histories.append(history)
# Out:
# Training model with batch size 16...
# Epoch 1/50
# 3125/3125 [==============================] - 18s 6ms/step - loss: 2.3056 - accuracy: 0.0987 - val_loss: 2.3043 - val_accuracy: 0.1000
# Epoch 2/50
# 3125/3125 [==============================] - 20s 6ms/step - loss: 2.3050 - accuracy: 0.0970 - val_loss: 2.3036 - val_accuracy: 0.1000
# Epoch 3/50
# 3125/3125 [==============================] - 18s 6ms/step - loss: 2.3045 - accuracy: 0.0996 - val_loss: 2.3032 - val_accuracy: 0.1000
# Epoch 4/50
# 3125/3125 [==============================] - 18s 6ms/step - loss: 2.3044 - accuracy: 0.0978 - val_loss: 2.3037 - val_accuracy: 0.1000
# Epoch 5/50
# 3125/3125 [==============================] - 18s 6ms/step - loss: 2.3043 - accuracy: 0.0981 - val_loss: 2.3035 - val_accuracy: 0.1000
# Epoch 6/50
# 3125/3125 [==============================] - 18s 6ms/step - loss: 2.3038 - accuracy: 0.1013 - val_loss: 2.3043 - val_accuracy: 0.1000
# Training model with batch size 32...
# Epoch 1/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 2.3034 - accuracy: 0.0975 - val_loss: 2.3029 - val_accuracy: 0.1000
# Epoch 2/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 2.3033 - accuracy: 0.0992 - val_loss: 2.3030 - val_accuracy: 0.1000
# Epoch 3/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 2.3033 - accuracy: 0.0975 - val_loss: 2.3029 - val_accuracy: 0.1000
# Epoch 4/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 2.3032 - accuracy: 0.0995 - val_loss: 2.3034 - val_accuracy: 0.1000
# Training model with batch size 64...
# Epoch 1/50
# 782/782 [==============================] - 6s 7ms/step - loss: 2.3030 - accuracy: 0.0984 - val_loss: 2.3028 - val_accuracy: 0.1000
# Epoch 2/50
# 782/782 [==============================] - 4s 5ms/step - loss: 2.3029 - accuracy: 0.0975 - val_loss: 2.3028 - val_accuracy: 0.1000
# Epoch 3/50
# 782/782 [==============================] - 4s 5ms/step - loss: 2.3029 - accuracy: 0.0987 - val_loss: 2.3028 - val_accuracy: 0.1000
# Epoch 4/50
# 782/782 [==============================] - 5s 7ms/step - loss: 2.3030 - accuracy: 0.0997 - val_loss: 2.3028 - val_accuracy: 0.1000
# Training model with batch size 128...
# Epoch 1/50
# 391/391 [==============================] - 3s 7ms/step - loss: 2.3028 - accuracy: 0.0993 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 2/50
# 391/391 [==============================] - 2s 6ms/step - loss: 2.3027 - accuracy: 0.0999 - val_loss: 2.3027 - val_accuracy: 0.1000
# Epoch 3/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.3028 - accuracy: 0.0987 - val_loss: 2.3027 - val_accuracy: 0.1000
# Epoch 4/50
# 391/391 [==============================] - 3s 7ms/step - loss: 2.3028 - accuracy: 0.0977 - val_loss: 2.3027 - val_accuracy: 0.1000
# Training model with batch size 256...
# Epoch 1/50
# 196/196 [==============================] - 2s 11ms/step - loss: 2.3027 - accuracy: 0.0983 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 2/50
# 196/196 [==============================] - 2s 9ms/step - loss: 2.3027 - accuracy: 0.0982 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 3/50
# 196/196 [==============================] - 2s 9ms/step - loss: 2.3027 - accuracy: 0.0987 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 4/50
# 196/196 [==============================] - 2s 9ms/step - loss: 2.3027 - accuracy: 0.0983 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 5/50
# 196/196 [==============================] - 2s 10ms/step - loss: 2.3027 - accuracy: 0.0973 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 6/50
# 196/196 [==============================] - 2s 10ms/step - loss: 2.3027 - accuracy: 0.0957 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 7/50
# 196/196 [==============================] - 2s 9ms/step - loss: 2.3027 - accuracy: 0.0985 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 8/50
# 196/196 [==============================] - 2s 10ms/step - loss: 2.3027 - accuracy: 0.0970 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 9/50
# 196/196 [==============================] - 2s 9ms/step - loss: 2.3027 - accuracy: 0.0961 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 10/50
# 196/196 [==============================] - 2s 9ms/step - loss: 2.3027 - accuracy: 0.0962 - val_loss: 2.3026 - val_accuracy: 0.1000

# %% [markdown]
# # Task 4 - Adding Regularisation
#
# The model as provided does not contain any regularisation techniques. Edit the model architecture to include at least two examples of regularisation. Retrain the model using the new architecture, and repeat the analysis performed in task 1.
#
# In your report, compare and contrast the results from this task, with those from the initial model configuration. Explain HOW and WHY the results are different, with consideration to the predicted classifications, losses and metrics.

# %%
### Update the model architecture to include at least two types of regularization.
### Train the model using the ideal settings found in previous tasks.

from tensorflow.keras import layers, regularizers

model = tf.keras.Sequential([
    layers.Conv2D(32, (3, 3), activation='relu', kernel_regularizer=regularizers.l2(0.001), input_shape=(32, 32, 3)),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(64, (3, 3), activation='relu', kernel_regularizer=regularizers.l2(0.001)),
    layers.MaxPooling2D((2, 2)),
    layers.Flatten(),
    layers.Dense(64, activation='relu', kernel_regularizer=regularizers.l1_l2(l1=0.001, l2=0.001)),
    layers.Dropout(0.5),
    layers.Dense(10)
])

# Compile the model
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# Train the model
history = model.fit(x_train, y_train, epochs=50, batch_size=128, validation_data=(x_test, y_test))


# Set the learning rate and batch size
learning_rate = 0.001
batch_size = 128

# Initialize the optimizer
optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)

# Compile the model
model.compile(optimizer=optimizer,
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# Train the model
history = model.fit(x_train, y_train, epochs=50, batch_size=batch_size, validation_data=(x_test, y_test))
# Out:
# Epoch 1/50
# 391/391 [==============================] - 6s 8ms/step - loss: 2.3150 - accuracy: 0.2815 - val_loss: 1.8497 - val_accuracy: 0.4095
# Epoch 2/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.8812 - accuracy: 0.3786 - val_loss: 1.7135 - val_accuracy: 0.4579
# Epoch 3/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.7918 - accuracy: 0.4120 - val_loss: 1.6788 - val_accuracy: 0.4711
# Epoch 4/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.7418 - accuracy: 0.4341 - val_loss: 1.6361 - val_accuracy: 0.4787
# Epoch 5/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.7192 - accuracy: 0.4453 - val_loss: 1.6368 - val_accuracy: 0.4940
# Epoch 6/50
# 391/391 [==============================] - 3s 6ms/step - loss: 1.7056 - accuracy: 0.4479 - val_loss: 1.6086 - val_accuracy: 0.4980
# Epoch 7/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.6835 - accuracy: 0.4588 - val_loss: 1.5747 - val_accuracy: 0.5009
# Epoch 8/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.6752 - accuracy: 0.4664 - val_loss: 1.6347 - val_accuracy: 0.4693
# Epoch 9/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.6624 - accuracy: 0.4710 - val_loss: 1.5601 - val_accuracy: 0.5048
# Epoch 10/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.6476 - accuracy: 0.4780 - val_loss: 1.5219 - val_accuracy: 0.5276
# Epoch 11/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.6440 - accuracy: 0.4792 - val_loss: 1.5521 - val_accuracy: 0.5125
# Epoch 12/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.6328 - accuracy: 0.4836 - val_loss: 1.5156 - val_accuracy: 0.5372
# Epoch 13/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.6358 - accuracy: 0.4856 - val_loss: 1.5392 - val_accuracy: 0.5194
# Epoch 14/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.6193 - accuracy: 0.4936 - val_loss: 1.4913 - val_accuracy: 0.5396
# Epoch 15/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.6082 - accuracy: 0.4955 - val_loss: 1.4733 - val_accuracy: 0.5546
# Epoch 16/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.5982 - accuracy: 0.5008 - val_loss: 1.4611 - val_accuracy: 0.5587
# Epoch 17/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.5932 - accuracy: 0.5060 - val_loss: 1.4546 - val_accuracy: 0.5661
# Epoch 18/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.5791 - accuracy: 0.5105 - val_loss: 1.4711 - val_accuracy: 0.5582
# Epoch 19/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.5694 - accuracy: 0.5154 - val_loss: 1.4343 - val_accuracy: 0.5706
# Epoch 20/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.5638 - accuracy: 0.5180 - val_loss: 1.4127 - val_accuracy: 0.5796
# Epoch 21/50
# 391/391 [==============================] - 3s 9ms/step - loss: 1.5582 - accuracy: 0.5244 - val_loss: 1.4568 - val_accuracy: 0.5681
# Epoch 22/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.5463 - accuracy: 0.5252 - val_loss: 1.4490 - val_accuracy: 0.5671
# Epoch 23/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.5468 - accuracy: 0.5266 - val_loss: 1.4155 - val_accuracy: 0.5866
# Epoch 24/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.5468 - accuracy: 0.5279 - val_loss: 1.4315 - val_accuracy: 0.5803
# Epoch 25/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.5330 - accuracy: 0.5330 - val_loss: 1.4167 - val_accuracy: 0.5910
# Epoch 26/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.5361 - accuracy: 0.5336 - val_loss: 1.3749 - val_accuracy: 0.5940
# Epoch 27/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.5247 - accuracy: 0.5389 - val_loss: 1.4212 - val_accuracy: 0.5858
# Epoch 28/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.5260 - accuracy: 0.5374 - val_loss: 1.3945 - val_accuracy: 0.5915
# Epoch 29/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.5193 - accuracy: 0.5383 - val_loss: 1.3858 - val_accuracy: 0.5920
# Epoch 30/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.5176 - accuracy: 0.5413 - val_loss: 1.3879 - val_accuracy: 0.5963
# Epoch 31/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.5155 - accuracy: 0.5432 - val_loss: 1.3766 - val_accuracy: 0.5958
# Epoch 32/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.5055 - accuracy: 0.5463 - val_loss: 1.3724 - val_accuracy: 0.6009
# Epoch 33/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.5057 - accuracy: 0.5454 - val_loss: 1.3811 - val_accuracy: 0.5997
# Epoch 34/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.4996 - accuracy: 0.5491 - val_loss: 1.3814 - val_accuracy: 0.5907
# Epoch 35/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.5049 - accuracy: 0.5474 - val_loss: 1.3569 - val_accuracy: 0.6081
# Epoch 36/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.4936 - accuracy: 0.5506 - val_loss: 1.3492 - val_accuracy: 0.6064
# Epoch 37/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.4897 - accuracy: 0.5512 - val_loss: 1.4112 - val_accuracy: 0.5843
# Epoch 38/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.4922 - accuracy: 0.5521 - val_loss: 1.3598 - val_accuracy: 0.6051
# Epoch 39/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.4898 - accuracy: 0.5537 - val_loss: 1.3612 - val_accuracy: 0.6057
# Epoch 40/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.4789 - accuracy: 0.5566 - val_loss: 1.3501 - val_accuracy: 0.6074
# Epoch 41/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.4881 - accuracy: 0.5515 - val_loss: 1.3534 - val_accuracy: 0.6047
# Epoch 42/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.4818 - accuracy: 0.5566 - val_loss: 1.3718 - val_accuracy: 0.5983
# Epoch 43/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.4776 - accuracy: 0.5578 - val_loss: 1.3415 - val_accuracy: 0.6028
# Epoch 44/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.4771 - accuracy: 0.5577 - val_loss: 1.3347 - val_accuracy: 0.6183
# Epoch 45/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.4724 - accuracy: 0.5597 - val_loss: 1.3571 - val_accuracy: 0.5985
# Epoch 46/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.4782 - accuracy: 0.5611 - val_loss: 1.3484 - val_accuracy: 0.6122
# Epoch 47/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.4724 - accuracy: 0.5585 - val_loss: 1.3464 - val_accuracy: 0.6119
# Epoch 48/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.4758 - accuracy: 0.5580 - val_loss: 1.3466 - val_accuracy: 0.6090
# Epoch 49/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.4757 - accuracy: 0.5579 - val_loss: 1.3574 - val_accuracy: 0.6126
# Epoch 50/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.4696 - accuracy: 0.5609 - val_loss: 1.3252 - val_accuracy: 0.6211
# Epoch 1/50
# 391/391 [==============================] - 5s 10ms/step - loss: 1.4704 - accuracy: 0.5609 - val_loss: 1.3210 - val_accuracy: 0.6159
# Epoch 2/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.4658 - accuracy: 0.5635 - val_loss: 1.3584 - val_accuracy: 0.6014
# Epoch 3/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.4612 - accuracy: 0.5621 - val_loss: 1.3279 - val_accuracy: 0.6173
# Epoch 4/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.4604 - accuracy: 0.5669 - val_loss: 1.3282 - val_accuracy: 0.6210
# Epoch 5/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.4620 - accuracy: 0.5642 - val_loss: 1.3352 - val_accuracy: 0.6134
# Epoch 6/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.4525 - accuracy: 0.5699 - val_loss: 1.3124 - val_accuracy: 0.6198
# Epoch 7/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.4574 - accuracy: 0.5632 - val_loss: 1.3239 - val_accuracy: 0.6188
# Epoch 8/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.4550 - accuracy: 0.5662 - val_loss: 1.3547 - val_accuracy: 0.6081
# Epoch 9/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.4480 - accuracy: 0.5700 - val_loss: 1.3578 - val_accuracy: 0.6064
# Epoch 10/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.4543 - accuracy: 0.5663 - val_loss: 1.3291 - val_accuracy: 0.6165
# Epoch 11/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.4493 - accuracy: 0.5689 - val_loss: 1.3150 - val_accuracy: 0.6213
# Epoch 12/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.4488 - accuracy: 0.5719 - val_loss: 1.3138 - val_accuracy: 0.6251
# Epoch 13/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.4428 - accuracy: 0.5738 - val_loss: 1.3085 - val_accuracy: 0.6189
# Epoch 14/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.4487 - accuracy: 0.5703 - val_loss: 1.3196 - val_accuracy: 0.6212
# Epoch 15/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.4409 - accuracy: 0.5724 - val_loss: 1.3074 - val_accuracy: 0.6232
# Epoch 16/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.4504 - accuracy: 0.5678 - val_loss: 1.3271 - val_accuracy: 0.6275
# Epoch 17/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.4472 - accuracy: 0.5697 - val_loss: 1.3166 - val_accuracy: 0.6245
# Epoch 18/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.4416 - accuracy: 0.5727 - val_loss: 1.3343 - val_accuracy: 0.6151
# Epoch 19/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.4367 - accuracy: 0.5722 - val_loss: 1.3180 - val_accuracy: 0.6233
# Epoch 20/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.4455 - accuracy: 0.5738 - val_loss: 1.3218 - val_accuracy: 0.6264
# Epoch 21/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.4387 - accuracy: 0.5712 - val_loss: 1.3006 - val_accuracy: 0.6222
# Epoch 22/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.4349 - accuracy: 0.5733 - val_loss: 1.3123 - val_accuracy: 0.6210
# Epoch 23/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.4304 - accuracy: 0.5755 - val_loss: 1.2840 - val_accuracy: 0.6295
# Epoch 24/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.4331 - accuracy: 0.5772 - val_loss: 1.2978 - val_accuracy: 0.6243
# Epoch 25/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.4305 - accuracy: 0.5779 - val_loss: 1.2938 - val_accuracy: 0.6320
# Epoch 26/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.4339 - accuracy: 0.5743 - val_loss: 1.3362 - val_accuracy: 0.6189
# Epoch 27/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.4268 - accuracy: 0.5785 - val_loss: 1.2960 - val_accuracy: 0.6292
# Epoch 28/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.4216 - accuracy: 0.5805 - val_loss: 1.3095 - val_accuracy: 0.6262
# Epoch 29/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.4300 - accuracy: 0.5788 - val_loss: 1.2856 - val_accuracy: 0.6309
# Epoch 30/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.4263 - accuracy: 0.5792 - val_loss: 1.3114 - val_accuracy: 0.6237
# Epoch 31/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.4290 - accuracy: 0.5775 - val_loss: 1.2979 - val_accuracy: 0.6220
# Epoch 32/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.4230 - accuracy: 0.5800 - val_loss: 1.3112 - val_accuracy: 0.6273
# Epoch 33/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.4285 - accuracy: 0.5763 - val_loss: 1.3143 - val_accuracy: 0.6186
# Epoch 34/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.4210 - accuracy: 0.5796 - val_loss: 1.3090 - val_accuracy: 0.6178
# Epoch 35/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.4147 - accuracy: 0.5828 - val_loss: 1.3017 - val_accuracy: 0.6296
# Epoch 36/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.4199 - accuracy: 0.5830 - val_loss: 1.2979 - val_accuracy: 0.6230
# Epoch 37/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.4097 - accuracy: 0.5840 - val_loss: 1.2669 - val_accuracy: 0.6318
# Epoch 38/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.4239 - accuracy: 0.5792 - val_loss: 1.2850 - val_accuracy: 0.6344
# Epoch 39/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.4198 - accuracy: 0.5823 - val_loss: 1.2934 - val_accuracy: 0.6355
# Epoch 40/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.4117 - accuracy: 0.5852 - val_loss: 1.2698 - val_accuracy: 0.6348
# Epoch 41/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.4138 - accuracy: 0.5831 - val_loss: 1.2674 - val_accuracy: 0.6348
# Epoch 42/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.4128 - accuracy: 0.5823 - val_loss: 1.2889 - val_accuracy: 0.6339
# Epoch 43/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.4145 - accuracy: 0.5842 - val_loss: 1.2917 - val_accuracy: 0.6262
# Epoch 44/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.4187 - accuracy: 0.5837 - val_loss: 1.3097 - val_accuracy: 0.6207
# Epoch 45/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.4105 - accuracy: 0.5852 - val_loss: 1.2577 - val_accuracy: 0.6438
# Epoch 46/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.4106 - accuracy: 0.5847 - val_loss: 1.2884 - val_accuracy: 0.6271
# Epoch 47/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.4060 - accuracy: 0.5851 - val_loss: 1.2811 - val_accuracy: 0.6384
# Epoch 48/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.4116 - accuracy: 0.5835 - val_loss: 1.2848 - val_accuracy: 0.6268
# Epoch 49/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.4128 - accuracy: 0.5839 - val_loss: 1.2732 - val_accuracy: 0.6353
# Epoch 50/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.4073 - accuracy: 0.5876 - val_loss: 1.2996 - val_accuracy: 0.6235

# %%
### Repeat your analysis from task 1, creating plots of the losses, metrics AND
### predicted classifications of images in the test set.

# Import libraries
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

# Load the data
(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()

# Normalize the data
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# Convert labels to one-hot encoding
num_classes = 10
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# Define the model architecture
model = keras.Sequential([
    keras.layers.Conv2D(32, (3,3), padding='same', activation='relu', input_shape=x_train.shape[1:]),
    keras.layers.MaxPooling2D((2,2)),
    keras.layers.Conv2D(64, (3,3), padding='same', activation='relu'),
    keras.layers.MaxPooling2D((2,2)),
    keras.layers.Flatten(),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(num_classes, activation='softmax')
])

# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
history = model.fit(x_train, y_train, epochs=10, validation_split=0.2)

# Generate predictions on the test set
y_pred = model.predict(x_test)

# Plot loss and accuracy for training and validation sets
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1,2,2)
plt.plot(history.history['accuracy'], label='train_acc')
plt.plot(history.history['val_accuracy'], label='val_acc')
plt.title('Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Define class names
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# Plot predicted classifications for test images
plt.figure(figsize=(10,10))
for i in range(10):
    # Find first example of each class that is predicted correctly and incorrectly
    correct_idx = np.argmax(y_test == i, axis=1)[np.argmax(y_pred == i, axis=1) == 1]
    incorrect_idx = np.argmax(y_test == i, axis=1)[np.argmax(y_pred == i, axis=1) == 0]

    # Plot correctly predicted image if there is at least one example
    if len(correct_idx) > 0:
        correct_idx = correct_idx[0]
        plt.subplot(10, 2, i*2+1)
        plt.imshow(x_test[correct_idx])
        plt.axis('off')
        plt.title('True: %s \n Predicted: %s'%(class_names[int(np.argmax(y_test[correct_idx]))], class_names[int(np.argmax(y_pred[correct_idx]))]))

    # Plot incorrectly predicted image if there is at least one example
    if len(incorrect_idx) > 0:
        incorrect_idx = incorrect_idx[0]
        plt.subplot(10, 2, i*2+2)
        plt.imshow(x_test[incorrect_idx])
        plt.axis('off')
        plt.title('True: %s \n Predicted: %s'%(class_names[int(np.argmax(y_test[incorrect_idx]))], class_names[int(np.argmax(y_pred[incorrect_idx]))]))
# Out:
# Epoch 1/10
# 1250/1250 [==============================] - 9s 6ms/step - loss: 1.4388 - accuracy: 0.4839 - val_loss: 1.1607 - val_accuracy: 0.5943
# Epoch 2/10
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.0605 - accuracy: 0.6305 - val_loss: 1.0165 - val_accuracy: 0.6445
# Epoch 3/10
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.9074 - accuracy: 0.6826 - val_loss: 0.9453 - val_accuracy: 0.6703
# Epoch 4/10
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.8078 - accuracy: 0.7174 - val_loss: 0.9589 - val_accuracy: 0.6720
# Epoch 5/10
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.7149 - accuracy: 0.7487 - val_loss: 0.9089 - val_accuracy: 0.6871
# Epoch 6/10
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6343 - accuracy: 0.7784 - val_loss: 0.9091 - val_accuracy: 0.6991
# Epoch 7/10
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.5579 - accuracy: 0.8047 - val_loss: 0.9407 - val_accuracy: 0.6894
# Epoch 8/10
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.4902 - accuracy: 0.8261 - val_loss: 0.9892 - val_accuracy: 0.6935
# Epoch 9/10
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.4224 - accuracy: 0.8516 - val_loss: 1.0357 - val_accuracy: 0.6920
# Epoch 10/10
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.3596 - accuracy: 0.8724 - val_loss: 1.1189 - val_accuracy: 0.6883
# 313/313 [==============================] - 1s 3ms/step
